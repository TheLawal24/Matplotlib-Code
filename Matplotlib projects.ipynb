# %% [markdown]
# # Matplotlib Project

# %%
from matplotlib import pylab
print(pylab.__version__)
# Out:
# 1.26.0

# %%
# Use Numpy to generate random data
import numpy as np

x = np.linspace(0,10,25)
y = x * x + 2
print(x)
print(y)
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]

# %%
x = np.linspace(0,10,25)
y = x * x + 2
print(x)
print(y)
print(np.array([x,y]).reshape(25,2))
# Out:
# [ 0.          0.41666667  0.83333333  1.25        1.66666667  2.08333333
#   2.5         2.91666667  3.33333333  3.75        4.16666667  4.58333333
#   5.          5.41666667  5.83333333  6.25        6.66666667  7.08333333
#   7.5         7.91666667  8.33333333  8.75        9.16666667  9.58333333
#  10.        ]
# [  2.           2.17361111   2.69444444   3.5625       4.77777778
#    6.34027778   8.25        10.50694444  13.11111111  16.0625
#   19.36111111  23.00694444  27.          31.34027778  36.02777778
#   41.0625      46.44444444  52.17361111  58.25        64.67361111
#   71.44444444  78.5625      86.02777778  93.84027778 102.        ]
# [[  0.           0.41666667]
#  [  0.83333333   1.25      ]
#  [  1.66666667   2.08333333]
#  [  2.5          2.91666667]
#  [  3.33333333   3.75      ]
#  [  4.16666667   4.58333333]
#  [  5.           5.41666667]
#  [  5.83333333   6.25      ]
#  [  6.66666667   7.08333333]
#  [  7.5          7.91666667]
#  [  8.33333333   8.75      ]
# ...

# %%
pylab.plot(x,y, 'r'); # 'r' stand for red

# %%
# Drawing  a Subgraph
pylab.subplot(1, 2, 1) # The content of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--') # The third paramenter here determines colour and line style
pylab.subplot(1, 2, 1)
pylab.plot(y, x,'g')

# %%
 # Drawing  a Subgraph
pylab.subplot(1, 2, 1) # The content of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--') # The third paramenter here determines colour and line style
pylab.subplot(1, 2, 2)
pylab.plot(y, x,'g');

# %%
#(1,2,1) and=(1,2,2) are significant if we want file subplot, without which both the graphs will be in the same plot

#for example
pylab.subplot(1, 2, 1) # The content of the brackets represent (rows, columns, indexes)
pylab.plot(x,y, 'r--') # The third paramenter here determines colour and line style
pylab.subplot(1, 2, 1)
pylab.plot(y, x,'g');

# %% [markdown]
# # Operation Description
# a = fig.add_ subplot(222)              =  initializes subplot
#
# fig, b-plt.subplots(nrows=3, nclose=2) = Adds Subplots
#
# ax = plt.subplots(2, 2)                = creates subplot

# %%
from matplotlib import pyplot as plt

# %%
fig=plt.figure()
axis = fig.add_axes([0.5, 0.1, 0.8, 0.8]) # control the left, right,width, height of the canvas (from 0 to 1)
axis.plot(x,y, 'g');

# %%
# Drawing more graphs
fig, axes = plt.subplots(nrows= 2, ncols=4) # submap is one row, 2 columns
for ax in axes:
    ax.plot(x,y, 'r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[28], line 4
#       2 fig, axes = plt.subplots(nrows= 2, ncols=4) # submap is one row, 2 columns
#       3 for ax in axes:
# ----> 4     ax.plot(x,y, 'r')
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
fig, axes = plt.subplots(nrows= 2, ncols=1) # submap is one row, 2 columns
for ax in axes:
    ax.plot(x,y, 'r')

# %%
# We can also put or draw a picture, or graph inside another graph
fig = plt.figure()
 
# Control the left, right, width, height of the canvas (from 0 to 1)
axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) # Bif axes
axes2 = fig.add_axes([0.2,0.6,0.2,0.2]) # small canvos

axes1.plot(x,y, 'r')
axes2.plot(x,y, 'b');

# %%
fig = plt.figure(figsize=(16,9), dpi=300) #New Graphics object
fig.add_subplot()
plt.plot(x,y, 'r');

# %%
fig, axes = plt.subplots(figsize=(16,9), dpi=50)
axes.set_xlabel("x-label")
axes.set_ylabel("y-label")

axes.set_title("title-graph")
axes.plot(x,y, "g");

# %%
ax.legend(["label1", "label2"])

fig, axes = plt.subplots()
axes.set_xlabel("x-label")
axes.set_ylabel("y-label")

axes.set_title("title-graph")

axes.plot(x, x**2)
axes.plot(y, y**3)

axes.legend(["y = x**2", "y= x**3"], loc = 2);

# %%
# In Matplotlib, you can set other properties such as line colour, transparency, and more.

fig, axes = plt.subplots(dpi=150)
axes.plot(x, x+1)
axes.plot(x, x+2)
axes.plot(x, x+3);

# %%
# In Matplotlib, you can set other properties such as line colour, transparency, and more.

fig, axes = plt.subplots(dpi=150)
axes.plot(x, x+1, color = 'red', alpha=.5)
axes.plot(x, x+2, color = 'blue')
axes.plot(x, x+3, color = 'green');

# %%
fig, axes = plt.subplots(dpi=150)

# Line width
axes.plot(x, x+1, color = 'red', linewidth = 0.25)
axes.plot(x, x+2, color = 'blue', linewidth = 1)
axes.plot(x, x+3, color = 'green', linewidth = 1.5)
axes.plot(x, x+4, color = 'yellow', linewidth = 2);

# %%
fig, ax = plt.subplots(dpi=100)

# Line width
ax.plot(x, x+1, color = 'red', marker='o')
ax.plot(x, x+2, color = 'blue', marker = '+')
ax.plot(x, x+3, color = 'green', marker = 's')
ax.plot(x, x+4, color = 'yellow', marker = '1')

ax.plot(x, x+5, color = 'black', marker='o', markersize=10)
ax.plot(x, x+6, color = 'blue', marker='s', markerfacecolor='red')
ax.plot(x, x+7, color = 'purple', marker='s',markersize=8, markerfacecolor='green')

# %%
### Set the canvas grid and axis range
fig, axes = plt.subplots(1,2, figsize=(10,5))

axes[0].plot(x, x**2, x**3, lw=2)
axes[0].grid(True)

# %%
### Set the canvas grid and axis range
fig, axes = plt.subplots(1,2, figsize=(10,5))

axes[0].plot(x, x**2, x**3, lw=2)
axes[0].grid(True)

axes[0].plot(x, x**2, x**3, lw=2)

axes[1].plot(x, x**2, x**3, lw=2)
axes[1].set_ylim([0, 60])
axes[1].set_xlim([2,5])
axes[1].grid(True)
# Out:
# (2.0, 5.0)

# %%
fig, axes = plt.subplots(1,2, figsize=(10,5))

axes[0].plot(x, x**2, x, x**3, lw=2)
axes[0].grid(True)

axes[1].plot(x, x**2, x, x**3, lw=2)

axes[1].set_ylim([0, 60])
axes[1].set_xlim([2,5])
axes[1].grid(True)

# %% [markdown]
# # 2D Graphics

# %%
n= np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1,4, figsize=(10,5))
axes[0].set_title("scatter")
axes[0].scatter(x, x+0.25*np.random.randn(len(x)))
axes[1].set_title("step")
axes[1].step(n, n**2,lw=2);

# %%
n= np.array([0,1,2,3,4,5])

fig, axes = plt.subplots(1,4, figsize=(10,5))
axes[0].set_title("scatter")
axes[0].scatter(x, x+0.25*np.random.randn(len(x)))
axes[1].set_title("step")
axes[1].step(n, n**2,lw=2)
axes[1].set_title("step")
axes[2].bar(n, n**2, align='center', width = 0.8, alpha= 0.5)
axes[3].set_title("fill_between")
axes[3].fill_between(x, x**2,x**3, color="green", alpha= 0.5)

# %%
## Draw a radar chart

fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0, 0.0, 1, 1], polar=True)
t= np.linspace(0,2 * np.pi, 100)
ax.plot(t,t, color='blue', lw=3);

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_axes([0.0, 0.0, 1, 1], polar=True)
t= np.linspace(0,2 * np.pi, 100)
ax.plot(t,t*5, color='blue', lw=3);

# %%
## Draw a histogram

n=np.random.randn(100000)
fig, axes = plt.subplots(1,2, figsize=(12,4))
axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("cummulative detailed histogram")
axes[1].hist(n, bins=8)
# Out:
# (array([1.2100e+02, 2.8160e+03, 1.9603e+04, 4.2324e+04, 2.8628e+04,
#         6.1010e+03, 3.9700e+02, 1.0000e+01]),
#  array([-4.15704365, -3.02231462, -1.88758559, -0.75285656,  0.38187247,
#          1.5166015 ,  2.65133054,  3.78605957,  4.9207886 ]),
#  <BarContainer object of 8 artists>)

# %%
n=np.random.randn(100000)
fig, axes = plt.subplots(1,2, figsize=(12,4))
axes[0].set_title("Default histogram")
axes[0].hist(n)

axes[1].set_title("cummulative detailed histogram")
axes[1].hist(n, cumulative=True, bins=8)
# Out:
# (array([1.0000e+01, 8.5500e+02, 1.0892e+04, 4.6664e+04, 8.5554e+04,
#         9.8606e+04, 9.9946e+04, 1.0000e+05]),
#  array([-4.64124406, -3.50185762, -2.36247117, -1.22308473, -0.08369828,
#          1.05568816,  2.19507461,  3.33446105,  4.4738475 ]),
#  <BarContainer object of 8 artists>)

# %%
# Draw contour image

import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt

delta = 0.025
x = np.arange(-3.0, 3.0, delta)
y = np.arange(-2.0, 2.0, delta)
X, Y = np.meshgrid(x,y)
Z1 = np.exp(-X**2 - Y**2)
Z2 = np.exp(-(-X - 1)**2 - (Y -1)**2)
z= (Z1 -Z2)*2

print(X)
print(Y)
# Out:
# [[-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  ...
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]
#  [-3.    -2.975 -2.95  ...  2.925  2.95   2.975]]
# [[-2.    -2.    -2.    ... -2.    -2.    -2.   ]
#  [-1.975 -1.975 -1.975 ... -1.975 -1.975 -1.975]
#  [-1.95  -1.95  -1.95  ... -1.95  -1.95  -1.95 ]
#  ...
#  [ 1.925  1.925  1.925 ...  1.925  1.925  1.925]
#  [ 1.95   1.95   1.95  ...  1.95   1.95   1.95 ]
#  [ 1.975  1.975  1.975 ...  1.975  1.975  1.975]]

# %%
fig, ax = plt.subplots()
CS = ax.contour(X, Y, z)
ax.clabel(CS, inline = 1, fontsize=10)
ax.set_title('contour map')
# Out:
# Text(0.5, 1.0, 'contour map')

# %%
# Draw a 3D surface image
from mpl_toolkits.mplot3d.axes3d import axes3D

fig = plt.figure(figsize=(14,6))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Draw a 3D surface image
# ----> 2 from mpl_toolkits.mplot3d.axes3d import axes3D
#       4 fig = plt.figure(figsize=(14,6))
#
# ImportError: cannot import name 'axes3D' from 'mpl_toolkits.mplot3d.axes3d' (C:\users\admin\desktop\my_project\env\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py)

# %%
# Specify the 3D graphics t draw, with projection '3D'
ax = fig.add_subplots(1,2,1, projection'3D')
